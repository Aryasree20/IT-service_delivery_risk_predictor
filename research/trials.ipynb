# %%
import gdown

# %%
url="https://drive.google.com/file/d/1kYFwueR5FKjDLMiSBmIS_FN-cnfDZ3-g/view?usp=drivesdk"

# %%
type(url)
# Out:
# str

# %%
file_id=url.split("/")[-2]
file_id
# Out:
# '1kYFwueR5FKjDLMiSBmIS_FN-cnfDZ3-g'

# %%
prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix+file_id, "deliver_risk_predictor.csv")
# Out:
# Downloading...
# From: https://drive.google.com/uc?/export=download&id=1kYFwueR5FKjDLMiSBmIS_FN-cnfDZ3-g
# To: d:\IT-service_delivery_risk_predictor\research\deliver_risk_predictor.csv
# 100%|██████████| 2.91M/2.91M [00:00<00:00, 4.35MB/s]
# 'deliver_risk_predictor.csv'
