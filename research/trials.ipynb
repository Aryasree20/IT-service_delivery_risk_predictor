# %%
import gdown

# %%
url="https://drive.google.com/file/d/1qTNNeyhbEnkQ3tkreL3IkdvfeTFnJ1Rb/view?usp=drive_link"

# %%
type(url)
# Out:
# str

# %%
file_id=url.split("/")[-2]
file_id
# Out:
# '1qTNNeyhbEnkQ3tkreL3IkdvfeTFnJ1Rb'

# %%
prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix+file_id, "deliver_risk_predictor.csv")
# Out:
# Downloading...
# From: https://drive.google.com/uc?/export=download&id=1qTNNeyhbEnkQ3tkreL3IkdvfeTFnJ1Rb
# To: d:\IT-service_delivery_risk_predictor\research\deliver_risk_predictor.csv
# 100%|██████████| 2.90M/2.90M [00:00<00:00, 14.6MB/s]
# 'deliver_risk_predictor.csv'
